# %%
import pandas as pd
from utils.load_data import load_data

# %%
df = pd.read_excel('../data/All Data.xlsx', sheet_name='coding')

# %%
df1 = load_data('synthetic', amount=1000, split_num=None, fillna=True)
df1
# Out:
# [IterativeImputer] Completing matrix with shape (1000, 11)
# [IterativeImputer] Change: 11884.407813435158, scaled tolerance: 713.623
# [IterativeImputer] Change: 2729.597130103415, scaled tolerance: 713.623
# [IterativeImputer] Change: 677.5722677063604, scaled tolerance: 713.623
# [IterativeImputer] Early stopping criterion reached.
#      Age  DrivingExp  Occupation  NCD  Make  Car.year      Car.price  InsCov  \
# 0     37           7          23  0.3    65        10  243347.300533      31
# 1     62          11           8  0.6    40        22  255972.837261       1
# 2     38           1          29  0.3    42         6  249941.000000      20
# 3     29           0          60  0.0    62         3  250313.000000      31
# 4     28           3           8  0.3     3         6  246460.414064      17
# ..   ...         ...         ...  ...   ...       ...            ...     ...
# 995   35           0          21  0.0    39         2  243647.368964      11
# ...

# %%
df2
# Out:
#      Age  DrivingExp  Occupation  NCD  Make  Car.year      Car.price  InsCov  \
# 0     40          11           6  0.6    42         3  241918.070561      12
# 1     52           3          28  0.3    21         4  241918.073293      17
# 2     31           2          66  0.6    14        14  241918.067447      25
# 3     57          11          34  0.0    42        17  241918.075056      31
# 4     46          11           6  0.6    64         8  250912.000000      12
# ..   ...         ...         ...  ...   ...       ...            ...     ...
# 695   35           8          26  0.0    39         6  241918.065940      31
# 696   64          11          53  0.6    21        22  241918.082614       4
# 697   33           8          30  0.2    25         6  241918.063322       5
# 698   42          11          36  0.6     2         2  241918.068081      18
# 699   38           2          28  0.0    65        21  241918.061391       6
#
#           Date
# 0   2023-06-26
# ...
