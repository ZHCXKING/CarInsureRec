# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor
from sdv.metadata import Metadata
from sdv.single_table import CTGANSynthesizer
from utils.fillna import iterative

# %%
df = pd.read_excel('../data/All Data.xlsx', sheet_name='coding')

# %%
df_imput = df.copy()
df_imput = iterative(df_imput, method='NB')
df_imput
# Out:
# [IterativeImputer] Completing matrix with shape (12925, 11)
# [IterativeImputer] Change: 758010.7930658503, scaled tolerance: 7000.0
# [IterativeImputer] Change: 503886.69504572486, scaled tolerance: 7000.0
# [IterativeImputer] Change: 499705.24159780313, scaled tolerance: 7000.0
# [IterativeImputer] Change: 87996.69173700346, scaled tolerance: 7000.0
# [IterativeImputer] Change: 43997.89419531839, scaled tolerance: 7000.0
# [IterativeImputer] Change: 28795.200586660514, scaled tolerance: 7000.0
# [IterativeImputer] Change: 18658.94049780433, scaled tolerance: 7000.0
# [IterativeImputer] Change: 11797.120796900865, scaled tolerance: 7000.0
# [IterativeImputer] Change: 7371.9914645849785, scaled tolerance: 7000.0
# [IterativeImputer] Change: 4584.869224909511, scaled tolerance: 7000.0
# [IterativeImputer] Early stopping criterion reached.
#        Age  DrivingExp  Occupation  NCD  Make  Car.year      Car.price  \
# 0       30           0          28  0.3    21        74  403690.149367
# 1       41           8          31  0.3    47        12   73520.771903
# 2       41           8          31  0.3    47        12   67497.924591
# 3       42           8          34  0.3    47        10  200385.120297
# 4       41           8          31  0.3    47        12   74131.000680
# ...    ...         ...         ...  ...   ...       ...            ...
# 12920   45          11          21  0.0    65         9   80000.000000
# 12921   46          11          23  0.2    16         0  305580.000000
# 12922   42          11          47  0.6     5        10  154147.788383
# 12923   43           5          23  0.4     3        11  158409.482444
# 12924   34           0          23  0.0    42        10   87815.484107
#
#        InsCov       Date
# 0          11 1901-01-04
# 1           5 2022-04-02
# 2           4 2022-04-04
# 3          25 2022-04-04
# 4           5 2022-04-06
# ...       ...        ...
# 12920       7 2025-12-03
# 12921      18 2025-12-03
# 12922      11 2025-12-03
# 12923      31 2025-12-04
# 12924      31 2025-12-04
#
# [12925 rows x 9 columns]

# %%
df_sdv = df.copy()
metadata = Metadata.load_from_json(filepath='../data/Metadata.json')
synthesizer = CTGANSynthesizer(metadata, epochs=300, verbose=True)
synthesizer.fit(df_sdv)
# Out:
# Gen. (-0.67) | Discrim. (-0.10): 100%|██████████| 1000/1000 [15:38<00:00,  1.07it/s]
