# %%
from utils.load_data import load_data

# %%
df1, df2 = load_data('original', amount=10000, split_num=500, fillna=True)
df1
# Out:
# [IterativeImputer] Completing matrix with shape (500, 11)
# [IterativeImputer] Change: 598647.4142740122, scaled tolerance: 864.49
# [IterativeImputer] Change: 7910.687555912327, scaled tolerance: 864.49
# [IterativeImputer] Change: 6240.761454785344, scaled tolerance: 864.49
# [IterativeImputer] Change: 4815.413393349948, scaled tolerance: 864.49
# [IterativeImputer] Change: 3663.3376024871072, scaled tolerance: 864.49
# [IterativeImputer] Change: 2771.787121905387, scaled tolerance: 864.49
# [IterativeImputer] Change: 2092.757265681671, scaled tolerance: 864.49
# [IterativeImputer] Change: 1578.7543333278948, scaled tolerance: 864.49
# [IterativeImputer] Change: 1190.6035348707476, scaled tolerance: 864.49
# [IterativeImputer] Change: 897.7665482611465, scaled tolerance: 864.49
# [IterativeImputer] Change: 676.9202382215399, scaled tolerance: 864.49
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (9500, 11)
# ...

# %%
df2
# Out:
#        Age  DrivingExp  Occupation  NCD       Date  Make  Car.year  Car.price  \
# 0     34.0         6.0        21.0  0.3 2023-08-15   5.0       8.0        NaN
# 1     40.0        11.0        28.0  0.4 2023-08-15  21.0      12.0        NaN
# 2     25.0         1.0         6.0  0.0 2023-08-15  29.0       5.0        NaN
# 3     36.0         3.0        64.0  0.4 2023-08-15  21.0       7.0        NaN
# 4     62.0         4.0        26.0  0.6 2023-08-15  21.0       9.0        NaN
# ...    ...         ...         ...  ...        ...   ...       ...        ...
# 9495  55.0        11.0         8.0  0.6 2025-02-07  65.0       6.0   500000.0
# 9496  41.0        11.0         6.0  0.6 2025-02-07  49.0      11.0    50000.0
# 9497  41.0         NaN        38.0  0.2 2025-02-07  65.0      15.0        NaN
# 9498  30.0         7.0        47.0  0.2 2025-02-07  14.0      11.0        NaN
# 9499  28.0         3.0        12.0  0.2 2025-02-07   5.0      13.0        NaN
#
#       InsCov
# 0         17
# ...
